# %%
from cs103 import *

# %% [markdown]
# ## Pre-Tutorial Work:
#
# Answer the "**thought question for pre-tutorial work**" below.

# %% [markdown]
# ## Setup
#
# We are going to continue to use the `CommunityGamingGrant` and `List[CommunityGamingGrant]` types (given below) in this problem set.
#
# Reminder: the CommunityGamingGrant type is based on the information about community gaming grants in BC between April 1, 2017 to July 13, 2018. Gaming grants are grants that the government gives to community organizations with lottery funds.
#
# |City|Organization|Grant Type|Grant Sector|Grant Subsector|Payment Amount|
# |---|---|---|---|---|---|
# |Abbotsford | Abbotsford Agrifair |	Community Gaming Grant | Arts and Culture | Fairs, Festivals, Museums	| 80000|
# |Abbotsford | Abbotsford BMX Society |	Community Gaming Grant | Sport | Sports for Youth | 29500|
# |Abbotsford | Fraser Valley Brain Injury Association |	Community Gaming Grant | Human and Social Services | Disadvantage Distress Poverty | 60000|
# |Abbotsford | Abbotsford International Airshow Society | Community Gaming Grant | Arts and Culture | Fairs, Festivals, Museums	| 60000|
#
#
# Source: DataBC. https://catalogue.data.gov.bc.ca/dataset/gaming-grants-paid-to-community-organizations/resource/7281e8ca-b649-4af9-b812-2a3e0bf8e4be (accessed: April 22, 2019)

# %%
from typing import NamedTuple, List

CommunityGamingGrant = NamedTuple('CommunityGamingGrant', [('city', str),      
                                                           ('org', str),   
                                                           ('type', str), 
                                                           ('sec', str),    
                                                           ('subsec', str),      
                                                           ('amt', int)])     # in range[0, ...)
# interp. community gaming grant data from BC. includes the city, organization ('org'), grant type ('type'),
#         grant sector ('sec'), grant subsector ('subsec'), and payment amount ('amt') in CAD
AGRIFAIR = CommunityGamingGrant("Abbotsford", 
                                "Abbotsford Agrifair", 
                                "Community Gaming Grant", 
                                "Arts and Culture", 
                                "Fairs, Festivals, Museums", 
                                80000)
BMX = CommunityGamingGrant("Abbotsford", 
                           "Abbotsford BMX Society", 
                           "Community Gaming Grant", 
                           "Sport", 
                           "Sports for Youth", 
                           29500)
BIA = CommunityGamingGrant("Abbotsford", 
                           "Fraser Valley Brain Injury Association", 
                           "Community Gaming Grant", 
                           "Human and Social services", 
                           "Disadvantage Distress Poverty", 
                           60000)
AIRSHOW = CommunityGamingGrant("Abbotsford", 
                               "Abbotsford International Airshow Society", 
                               "Community Gaming Grant", 
                               "Arts and Culture", 
                               "Fairs, Festivals, Museums", 
                               60000)
ARTS_COUNCIL = CommunityGamingGrant("Burnaby",
                                    "Burnaby Arts Council", 
                                    "Community Gaming Grant", 
                                    "Arts and Culture", 
                                    "Adult Arts and Culture", 
                                    15100)
BARRACUDAS = CommunityGamingGrant("Burnaby", 
                                  "Burnaby Barracuda Summer Aquatics Club", 
                                  "Community Gaming Grant", 
                                  "Sport", 
                                  "Sports for Youth", 
                                  51900)
AFRICAN_DESCENT_SOCIETY = CommunityGamingGrant("Vancouver", 
                                               "African Descent Society British Columbia", 
                                               "Community Gaming Grant", 
                                               "Arts and Culture", 
                                               "Fairs, Festivals, Museums", 
                                               25000)
ALL_BODIES = CommunityGamingGrant("Vancouver", 
                                  "All Bodies Dance Society", 
                                  "Community Gaming Grant", 
                                  "Arts and Culture", 
                                  "Adult Arts and Culture",   
                                  12000)

YOUTH_MUSIC = CommunityGamingGrant("Richmond", 
                                   "BC Youth Music Society", 
                                   "Community Gaming Grant", 
                                   "Arts and Culture", 
                                   "Adult Arts and Culture",   
                                   31500)
CHINESE_ORCHESTRA = CommunityGamingGrant("Richmond", 
                                         "Canadian YC Chinese Orchestra Association",
                                         "Community Gaming Grant", 
                                         "Arts and Culture", 
                                         "Adult Arts and Culture",   
                                         5000)

# template based on compound
def fn_for_community_gaming_grant(cg: CommunityGamingGrant) -> ...:
    return ...(cg.city,
               cg.org,
               cg.type,
               cg.sec,
               cg.subsec,
               cg.amt)


# List[CommunityGamingGrant]
# interp. a list of community grants

L0 = []
L1 = [AGRIFAIR, 
      BMX, 
      BIA, 
      AIRSHOW, 
      ARTS_COUNCIL, 
      BARRACUDAS, 
      AFRICAN_DESCENT_SOCIETY, 
      ALL_BODIES, 
      YOUTH_MUSIC, 
      CHINESE_ORCHESTRA]

# template based on arbitrary-sized and the reference rule
def fn_for_locg(locg: List[CommunityGamingGrant]) -> ...:
    # description of the acc
    acc = ... # type: ...
    for cg in locg:
        acc = ...(acc, fn_for_community_gaming_grant(cg))
    return ...(acc)

# %% [markdown]
# ## Problem 1
#
# Design a function that takes a grant sector, maximum grant amount, and a list of community grants and returns the community grants for the given sector of at most the given maximum grant amount.
#
# In particular, the **function MUST operate in two steps**. First, it will find the community grants for the given grant sector, then it will find which of those community grants received at most the maximum grant amount.
#
# Remember to follow the HtDF recipe and the helper rules.
#
# **Thought question for pre-tuorial work:** Which helper rule applies because of the requirement to operate in two steps?

# %%
# your solution goes here

# %%
# NOTE: You should not be able to edit this cell. Just run it to start the process of submiting your code.
from cs103 import submit

COURSE = 72592
ASSIGNMENT = 889061

submit(COURSE, ASSIGNMENT)

# If your submission fails, SUBMIT ANYWAY by downloading your files and uploading 
# them to Canvas. You can learn how on the page "How to submit your Jupyter notebook" 
# on our Canvas site.
